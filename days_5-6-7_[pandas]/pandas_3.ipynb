# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/TOSHIBA/Downloads/2021_population.csv')

# %%
df
# Out:
#     iso_code           country 2021_last_updated 2020_population  \
# 0        CHN             China     1,447,065,329   1,439,323,776
# 1        IND             India     1,401,310,563   1,380,004,385
# 2        USA     United States       334,058,426     331,002,651
# 3        IDN         Indonesia       278,037,263     273,523,615
# 4        PAK          Pakistan       227,724,796     220,892,340
# ..       ...               ...               ...             ...
# 219      MSR        Montserrat             4,977           4,992
# 220      FLK  Falkland Islands             3,533           3,480
# 221      NIU              Niue             1,619           1,626
# 222      TKL           Tokelau             1,373           1,357
# 223      VAT      Vatican City               800             801
#
#                 area density_sq_km growth_rate world_%  rank
# 0    9,706,961 sq_km     149/sq_km       0.34%  18.34%     1
# 1    3,287,590 sq_km     424/sq_km       0.97%  17.69%     2
# ...

# %% [markdown]
# # Size

# %%
df.size
# Out:
# 2016

# %% [markdown]
# # Number of Dimnshen

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# # Describe

# %%
df.describe()
# Out:
#              rank
# count  224.000000
# mean   115.013393
# std     66.844876
# min      1.000000
# 25%     57.750000
# 50%    113.500000
# 75%    171.250000
# max    232.000000

# %% [markdown]
# # Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   iso_code           224 non-null    object
#  1   country            224 non-null    object
#  2   2021_last_updated  224 non-null    object
#  3   2020_population    224 non-null    object
#  4   area               224 non-null    object
#  5   density_sq_km      224 non-null    object
#  6   growth_rate        224 non-null    object
#  7   world_%            224 non-null    object
#  8   rank               224 non-null    int64
# dtypes: int64(1), object(8)
# memory usage: 15.9+ KB

# %% [markdown]
# # Shape

# %%
df.shape
# Out:
# (224, 9)

# %% [markdown]
# # isnull

# %%
df.isnull()
# Out:
#      iso_code  country  2021_last_updated  2020_population   area  \
# 0       False    False              False            False  False
# 1       False    False              False            False  False
# 2       False    False              False            False  False
# 3       False    False              False            False  False
# 4       False    False              False            False  False
# ..        ...      ...                ...              ...    ...
# 219     False    False              False            False  False
# 220     False    False              False            False  False
# 221     False    False              False            False  False
# 222     False    False              False            False  False
# 223     False    False              False            False  False
#
#      density_sq_km  growth_rate  world_%   rank
# 0            False        False    False  False
# 1            False        False    False  False
# ...

# %%
df2 = pd.read_csv(r'C:\Users\TOSHIBA\Desktop\k.csv')

# %%
df2
# Out:
#                                               iso_code       country  \
# 0    CHN,China,"1,447,065,329","null","9,706,961 sq...           NaN
# 1    IND,India,"1,401,310,563","1,380,004,385","3,2...           NaN
# 2    USA,United States,"334,058,426","331,002,651",...           NaN
# 3    IDN,Indonesia,"278,037,263","273,523,615","1,9...           NaN
# 4    PAK,Pakistan,"227,724,796","220,892,340","881,...           NaN
# ..                                                 ...           ...
# 219  MSR,Montserrat,"4,977","4,992",102 sq_km,49/sq...           NaN
# 220  FLK,Falkland Islands,"3,533","3,480","12,173 s...           NaN
# 221  NIU,Niue,"1,619","1,626",260 sq_km,6/sq_km,-0....           NaN
# 222  TKL,Tokelau,"1,373","1,357",12 sq_km,114/sq_km...           NaN
# 223                                                VAT  Vatican City
#
#      2021_last_updated  2020_population     area density_sq_km growth_rate  \
# ...

# %%
df2.isnull()
# Out:
#      iso_code  country  2021_last_updated  2020_population   area  \
# 0       False    False              False             True  False
# 1       False    False              False            False  False
# 2       False    False              False            False  False
# 3       False    False              False            False  False
# 4       False    False              False            False  False
# ..        ...      ...                ...              ...    ...
# 219     False    False              False            False  False
# 220     False    False              False            False  False
# 221     False    False              False            False  False
# 222     False    False              False            False  False
# 223     False    False              False            False  False
#
#      density_sq_km  growth_rate  world_%   rank
# 0            False        False    False  False
# 1            False        False    False  False
# ...
